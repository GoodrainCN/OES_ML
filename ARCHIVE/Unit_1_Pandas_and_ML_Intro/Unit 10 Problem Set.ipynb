# %% [markdown]
# 1.) Once again, read in the file '2002FemPreg.csv'. Strip any whitespace from the column names.

# %%
#insert 1
import pandas as pd
preg = pd.read_csv('2002FemPreg.csv', index_col = 0)
preg.columns = preg.columns.str.strip()
preg
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %% [markdown]
# 2.) Reduce the dataframe to only contain data on live births (meaning the preg.outcome == 1).

# %%
#insert 2
preg[preg.outcome == 1]
preg[preg['outcome'] == 1]
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13581   12568         2        NaN        NaN       NaN       NaN       5.0
# 13584   12569         2        NaN        NaN       NaN       NaN       6.0
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %% [markdown]
# 3.) Find the attribute that represents the mother's age. What is it called? What index is it in?

# %%
#insert 3
for i,column in enumerate(preg.columns):
    if 'age' in column:
        print(i,column, preg[column].mean())
# Out:
# 15 ageatend 25.935455349248453
# 16 hpageend 29.951899358658114
# 40 kidage 111.8579408543264
# 41 hpagelb 27.848682754040293
# 67 lastage 87.34281437125749
# 77 ageqtnur_n 8.374802438473695
# 78 ageqtnur_p 1.2171260732037958
# 79 ageqtnur 6.87008585630366
# 85 lastage2 41.68
# 95 ageqtnur_n2 5.940298507462686
# 96 ageqtnur_p2 1.1940298507462686
# 97 ageqtnur2 5.402985074626866
# 103 lastage3 24.4
# 113 ageqtnur_n3 2.0
# 114 ageqtnur_p3 1.0
# 115 ageqtnur3 2.0
# 161 agepreg 24.688151197038128
# 163 agecon 2420.70977709115
# 179 ager 33.470904141837714
# 180 agescrn 33.470904141837714
# 203 agepreg_i 0.01846538659604208
# 205 agecon_i 0.0158905318914147
# 220 ager_i 0.0

# %% [markdown]
# 4.) Reduce the data frame further to consider data for only non-null birthwgt_lb and mother's age values.

# %%
#insert 4
preg.dropna(subset = ['birthwgt_lb', 'agepreg'], inplace = True)
preg
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13581   12568         2        NaN        NaN       NaN       NaN       5.0
# 13584   12569         2        NaN        NaN       NaN       NaN       6.0
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %% [markdown]
# 5.) Update the mother's age column so that the ages are no longer decimals but rounded down integers. Meaning, if the woman's age is saved as 47.8, then re-save it as 47. Hint: recast the column data type as an integer.

# %%
print(len(preg.columns))
# Out:
# 244

# %%
#insert 5
preg['agepreg'] = preg['agepreg'].astype(int)
#preg.info()
preg['agepreg']
# Out:
# 0        33
# 1        39
# 2        14
# 3        17
# 4        18
#          ..
# 13581    30
# 13584    26
# 13588    17
# 13591    21
# 13592    21
# Name: agepreg, Length: 9084, dtype: int64

# %% [markdown]
# 6.) Make a histogram of the womens' ages. Label axes and give a title.

# %%
#insert 6
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

age = preg.agepreg
age = age.dropna()
print(len(age))
age.describe()
age.value_counts().sort_index()
age.plot.hist(edgecolor="black", bins=np.arange(0,50,1))
##plt.xlabel('age')
plt.xlabel('age')
# Out:
# 9084
# Text(0.5, 0, 'age')

# %% [markdown]
# 7.) Create a frequency chart in descending order of age frequency.

# %%
#insert 7
preg.agepreg.value_counts(ascending = False)
# Out:
# 21    641
# 20    632
# 23    590
# 24    560
# 19    558
# 22    552
# 18    541
# 26    514
# 25    509
# 27    486
# 28    444
# 17    397
# 30    394
# 29    393
# 31    338
# 32    277
# 16    237
# 33    219
# 34    171
# 35    136
# 15    127
# 36     99
# 37     83
# 38     54
# 14     43
# 39     34
# 40     20
# 13     14
# 41     13
# 10      2
# 42      2
# 11      1
# 12      1
# 44      1
# 43      1
# Name: agepreg, dtype: int64

# %% [markdown]
# 8.) Create a frequency chart in ascending order of age.

# %%
#insert 8
preg.agepreg.value_counts().sort_index()
# Out:
# 10      2
# 11      1
# 12      1
# 13     14
# 14     43
# 15    127
# 16    237
# 17    397
# 18    541
# 19    558
# 20    632
# 21    641
# 22    552
# 23    590
# 24    560
# 25    509
# 26    514
# 27    486
# 28    444
# 29    393
# 30    394
# 31    338
# 32    277
# 33    219
# 34    171
# 35    136
# 36     99
# 37     83
# 38     54
# 39     34
# 40     20
# 41     13
# 42      2
# 43      1
# 44      1
# Name: agepreg, dtype: int64

# %% [markdown]
# 9.) How old was the youngest and oldest mother in the survey and how much did their baby weigh?

# %%
list0 = preg.agepreg.value_counts(ascending = True)
length = len(list0)
print(length)
count = 0
for i in list0:
    #print(i)
    count += 1
    if count == 1:
        smallest = i
    elif count == 34:
        largest = i
print(largest)
print(smallest)
# Out:
# 35
# 632
# 1

# %%
#insert 9
largest = preg[preg['agepreg'] == 43]
largest_age = largest['agepreg']
largest_wgt = largest['totalwgt_lb']
for i in largest_age:
    largest_age = i
for i in largest_wgt:
    largest_wgt = i
print(f"The largest age is {largest_age}")
print(f"and the baby weigh is {largest_wgt}")
print()
smallest = preg[preg['agepreg'] == 10]
smallest_age = smallest['agepreg']
smallest_wgt = smallest['totalwgt_lb']
for i in smallest_age:
    #print(i)
    smallest_age = i
for i in smallest_wgt:
    smallest_wgt = i
print(f"The smallest age is {smallest_age}")
print(f"and the baby weigh is {smallest_wgt}")
# Out:
# The largest age is 43
# and the baby weigh is 6.8125
#
# The smallest age is 10
# and the baby weigh is 8.5

# %% [markdown]
# 10.) What is the average woman's age? What is the woman's age in the 25th quartile? The 75th?

# %%
#insert 10
preg.agepreg.describe()
# Out:
# count    9084.000000
# mean       24.481286
# std         5.572457
# min        10.000000
# 25%        20.000000
# 50%        24.000000
# 75%        28.000000
# max        44.000000
# Name: agepreg, dtype: float64

# %% [markdown]
# 11.) Find the average birthweight for the mothers in the youngest quartile and in the oldest quartile. Might younger mothers tend to have heavier babies?

# %%
#insert 11
print(f"The youngest quartile {preg[preg.agepreg <= 20].totalwgt_lb.mean()}")
print(f"the oldest quartile {preg[preg.agepreg >= 28].totalwgt_lb.mean()}")
# Out:
# The youngest quartile 7.1012150728059815
# the oldest quartile 7.369950206689214

# %% [markdown]
# 12.) Make a comparative histogram of baby weights for mothers in the youngest and oldest quartile.

# %%
#insert 12
from scipy import stats

#s_quartile = preg[preg.agepreg <= 20].totalwgt_lb
#l_quartile = preg[preg.agepreg >= 28].totalwgt_lb
#plt.figure(figsize=(12,8))

#line0 = np.linspace(0, 15, len(s_quartile))
#m,s = stats.norm.fit(s_quartile)
#pdf_g = stats.norm.pdf(line0, m, s)
#plt.plot(line0, pdf_g, color = 'blue')

#line1 = np.linspace(0, 15, len(l_quartile))
#m,s = stats.norm.fit(l_quartile)
#pdf_g = stats.norm.pdf(line1, m, s)
#plt.plot(lin1, pdf_g, color = 'orange')

first_q = preg[preg.agepreg <= 20].totalwgt_lb
third_q = preg[preg.agepreg >= 28].totalwgt_lb

plt.hist([first_q, third_q], np.arange(-0.5, 15.5, 1), label=['Age in First Quartile', 'Age in Fourth Quartile'])
plt.xlabel('Baby Weight', size=20)
plt.ylabel('Percentage', size=20)
plt.legend()
plt.show()

# %% [markdown]
# By the way, where did this large pregnancy dataset come from? I found it in a super amazing open resource, online Python statistics book called Think Stats. You should check out all of the modules here: http://greenteapress.com/thinkstats/
#
# The dataset itself is obtained from the CDC's 2002 Cycle 6
