# %% [markdown]
# ### Learning Pandas Problem Set
#
# Getting comfortable with Pandas will make your Machine Learning life much easier and vastly improve your ability to analyze data.
#
# One of the fundamental **Learning Outcomes** for this course is:
#
#     Demonstrating facility with loading, viewing, manipulating, transforming and analyzing data using the Pandas library in Python
#
#
# Some of these problem set questions should help you build this facility.

# %% [markdown]
# #### Part 0: Prepare Demo of one skill
# Prepare a one minute presentation with examples where you explain that Pandas skill. Explain when and how you would use it and give examples.  If possible, give counter examples as well (when NOT to use it or how NOT to use it).  Use the topic that was assigned to you in class.

# %% [markdown]
# 1) Once again, read in the file '2002FemPreg.csv'. Strip any whitespace from the column names.

# %%
# insert 1
import pandas as pd
preg = pd.read_csv('data/2002FemPreg.csv', index_col=0)
preg.columns = preg.columns.str.strip()
preg
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %% [markdown]
# 2) Reduce the dataframe to only contain data on live births (meaning the preg.outcome == 1).

# %%
# insert 2
preg = preg[preg['outcome'] == 1]
preg
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13581   12568         2        NaN        NaN       NaN       NaN       5.0
# 13584   12569         2        NaN        NaN       NaN       NaN       6.0
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %% [markdown]
# 3) Reduce the data frame further to consider data for only non-null baby weights (totalwgt_lb) and non-null mother's age values (agepreg).

# %%
# insert 3
preg = preg.dropna(subset = ['totalwgt_lb', 'agepreg'])
preg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9038 entries, 0 to 13592
# Columns: 244 entries, caseid to totalwgt_lb
# dtypes: float64(171), int64(73)
# memory usage: 16.9 MB

# %% [markdown]
# 4) Update the mother's age column so that the ages are no longer decimals but rounded down integers. Meaning, if the woman's age is saved as 47.8, then re-save it as 47. Hint: recast the column data type as an integer.

# %%
# insert 4
preg['agepreg'] = preg['agepreg'].astype(int)
preg['agepreg']
# Out:
# C:\Users\goodr\AppData\Local\Temp\ipykernel_33516\4137941765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preg['agepreg'] = preg['agepreg'].astype(int)
# 0        33
# 1        39
# 2        14
# 3        17
# 4        18
#          ..
# 13581    30
# 13584    26
# 13588    17
# 13591    21
# 13592    21
# Name: agepreg, Length: 9038, dtype: int32

# %% [markdown]
# 5) Make a histogram of the womens' ages. Label axes and give a title.

# %%
# insert 5
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

age = preg.agepreg
age = age.dropna()
print(len(age))
age.describe()
age.value_counts().sort_index()
age.plot.hist(edgecolor="black", bins=np.arange(0,50,1))
##plt.xlabel('age')
plt.xlabel('age')
plt.title("women's age")
# Out:
# 9038
# Text(0.5, 1.0, "women's age")

# %% [markdown]
# 6) Create a frequency chart in descending order of age frequency.

# %%
# insert 6
preg.agepreg.value_counts(ascending = False)
# Out:
# 21    636
# 20    631
# 23    588
# 24    558
# 19    557
# 22    549
# 18    539
# 26    512
# 25    508
# 27    485
# 28    439
# 17    393
# 30    392
# 29    392
# 31    336
# 32    276
# 16    237
# 33    218
# 34    171
# 35    133
# 15    126
# 36     98
# 37     82
# 38     54
# 14     43
# 39     34
# 40     19
# 41     13
# 13     11
# 10      2
# 42      2
# 43      1
# 12      1
# 11      1
# 44      1
# Name: agepreg, dtype: int64

# %% [markdown]
# 7) Create a frequency chart in ascending order of age.

# %%
# insert 7
preg.agepreg.value_counts().sort_index()
# Out:
# 10      2
# 11      1
# 12      1
# 13     11
# 14     43
# 15    126
# 16    237
# 17    393
# 18    539
# 19    557
# 20    631
# 21    636
# 22    549
# 23    588
# 24    558
# 25    508
# 26    512
# 27    485
# 28    439
# 29    392
# 30    392
# 31    336
# 32    276
# 33    218
# 34    171
# 35    133
# 36     98
# 37     82
# 38     54
# 39     34
# 40     19
# 41     13
# 42      2
# 43      1
# 44      1
# Name: agepreg, dtype: int64

# %% [markdown]
# 8) How old was the youngest and oldest mother in the survey and how much did their baby weigh?

# %%
# insert 8
print(f"yougest mother age: {preg.agepreg.min()}")
print(f"yougest mother's baby weight: {preg.totalwgt_lb[preg.agepreg.min()]}")
print(f"the oldest mother age: {preg.agepreg.max()}")
print(f"oldest mother's baby weight: {preg.totalwgt_lb[preg.agepreg.max()]}")
# Out:
# yougest mother age: 10
# yougest mother's baby weight: 7.8125
# the oldest mother age: 44
# oldest mother's baby weight: 7.9375

# %% [markdown]
# 9) What is the average woman's age? What is the woman's age in the 25th quartile? The 75th?

# %%
# insert 9
print(f"average woman's age{preg.agepreg.mean()}")
print(f"25th quartile: {preg.agepreg.quantile(0.25)}")
print(f"75th quartile: {preg.agepreg.quantile(0.75)}")
# Out:
# average woman's age24.47975215755698
# 25th quartile: 20.0
# 75th quartile: 28.0

# %% [markdown]
# 10) Find the average birthweight for the mothers in the youngest quartile and in the oldest quartile. Might younger mothers tend to have heavier babies?

# %%
# insert 10
print(f"The youngest quartile {preg[preg.agepreg <= 20].totalwgt_lb.mean()}")
print(f"the oldest quartile {preg[preg.agepreg >= 28].totalwgt_lb.mean()}")
# Out:
# The youngest quartile 7.1012150728059815
# the oldest quartile 7.369950206689214

# %% [markdown]
# 11) Make a comparative histogram of baby weights for mothers in the youngest and oldest quartile.

# %%
# insert 11
first_q = preg[preg.agepreg <= 20].totalwgt_lb
third_q = preg[preg.agepreg >= 28].totalwgt_lb

plt.hist([first_q, third_q], np.arange(-0.5, 15.5, 1), label=['Age in First Quartile', 'Age in Fourth Quartile'])
plt.title('percentage & baby weight')
plt.xlabel('Baby Weight', size=20)
plt.ylabel('Percentage', size=20)
plt.legend()
plt.show()

# %% [markdown]
# ---
# * By the way, where did this large pregnancy dataset come from? I found it in a super amazing open resource, online Python statistics book called Think Stats. You should check out all of the modules here: http://greenteapress.com/thinkstats/
#
# The dataset itself is obtained from the CDC's 2002 Cycle 6
#
# ---

# %% [markdown]
# 12) Read the `NBA_season1718_salary.csv` file into a Pandas dataframe.
#
# Answer the following questions about the data (put your answers in this Markdown Cell)
# 1) What was the mean and median NBA player salary across all teams in 2017-18?
#
# 2) Who was the second highest paid Blazer in 2017-2018?
#
# 3) What team had the highest average salary per player?  What was that average salary? (you may want to read about the groupby method in Pandas)
#
# 4) What NBA team had the most expensive total roster in 2017-2018?

# %%
# code for 12
import pandas as pd
nba = pd.read_csv('NBA_season1718_salary.csv', index_col = 0)
nba.columns = nba.columns.str.strip()
print(f"mean salary: {nba.season17_18.mean()}")
print(f"median salary: {nba.season17_18.median()}")
print()

sorted_list0 = nba.season17_18.value_counts().sort_index(ascending = False)
print(f"second high paid: {sorted_list0.index[1]}")

temp = nba.groupby("Tm").agg({'season17_18': 'mean'})
print(f"the highest paid team: {temp.index[0]}")
print(f"the highest team's salary: {temp.iloc[0][0]}")
print()

temp0 = nba.groupby("Tm").agg({'season17_18': 'sum'})
print(f"the highest roster team: {temp0.index[0]}")
print(f"the highest team's roster fee: {temp0.iloc[0][0]}")
# Out:
# mean salary: 5858945.886561954
# median salary: 2386864.0
#
# second high paid: 33285709.0
# the highest paid team: ATL
# the highest team's salary: 3711770.2592592593
#
# the highest roster team: ATL
# the highest team's roster fee: 100217797.0

# %% [markdown]
# 13) Visit the [Kaggle Datasets](https://www.kaggle.com/datasets) repository and download a dataset that looks interesting to you.  Use Pandas to explore the data and then Ask and answer 3 interesting questions about that data below.

# %%
# question 1: Open the dataset and strip away white spaces
# answer:
import pandas as pd
df = pd.read_csv('data/FL.csv', index_col = 0)
df.columns = df.columns.str.strip()

# question 2: clean the category of new_case and tot_case, left only valid value
# answer:
df = df.dropna(subset = ['new_case', 'tot_cases'])


# question 3: plot the graph for the new_case
# answer:
plt.plot(df.new_case)
plt.xticks(
    [0,100,200,300,400,500,600,700],
    ['2020/1','2020/5', '2020/8', '2020/12', '2021/2', '2021/6', '2021/9', '2021/12']
)
plt.xlabel('date')
plt.ylabel('cases')
plt.title('daily new cases')
# Out:
# Text(0.5, 1.0, 'daily new cases')
